# %% [markdown]
# Installation

# %%
# !pip install open3d
# !pip install cloudpickle
# requires also PyTorch but I am not putting install command for it here as it is best to install the proper version for you system
# Out:
# Requirement already satisfied: open3d in c:\users\rados\anaconda3\lib\site-packages (0.9.0.0)
# Requirement already satisfied: ipywidgets in c:\users\rados\anaconda3\lib\site-packages (from open3d) (7.5.1)
# Requirement already satisfied: widgetsnbextension in c:\users\rados\anaconda3\lib\site-packages (from open3d) (3.5.1)
# Requirement already satisfied: notebook in c:\users\rados\anaconda3\lib\site-packages (from open3d) (6.0.3)
# Requirement already satisfied: numpy in c:\users\rados\anaconda3\lib\site-packages (from open3d) (1.16.5)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\rados\anaconda3\lib\site-packages (from ipywidgets->open3d) (4.3.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\rados\anaconda3\lib\site-packages (from ipywidgets->open3d) (5.1.4)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\rados\anaconda3\lib\site-packages (from ipywidgets->open3d) (7.13.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\rados\anaconda3\lib\site-packages (from ipywidgets->open3d) (5.0.4)
# Requirement already satisfied: tornado>=5.0 in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (6.0.4)
# Requirement already satisfied: ipython-genutils in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (0.2.0)
# Requirement already satisfied: prometheus-client in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (0.7.1)
# Requirement already satisfied: nbconvert in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (18.1.1)
# Requirement already satisfied: Send2Trash in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (1.5.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (6.1.0)
# Requirement already satisfied: jinja2 in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (2.11.1)
# Requirement already satisfied: terminado>=0.8.1 in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\rados\anaconda3\lib\site-packages (from notebook->open3d) (4.6.1)
# Requirement already satisfied: six in c:\users\rados\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets->open3d) (1.14.0)
# Requirement already satisfied: decorator in c:\users\rados\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets->open3d) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\rados\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (46.1.1.post20200323)
# Requirement already satisfied: backcall in c:\users\rados\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (0.1.0)
# Requirement already satisfied: pygments in c:\users\rados\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (2.6.1)
# Requirement already satisfied: pickleshare in c:\users\rados\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\rados\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (0.15.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\rados\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (3.0.4)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\rados\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (0.4.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\rados\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->open3d) (3.2.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\rados\anaconda3\lib\site-packages (from nbconvert->notebook->open3d) (0.3)
# Requirement already satisfied: defusedxml in c:\users\rados\anaconda3\lib\site-packages (from nbconvert->notebook->open3d) (0.6.0)
# Requirement already satisfied: testpath in c:\users\rados\anaconda3\lib\site-packages (from nbconvert->notebook->open3d) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\rados\anaconda3\lib\site-packages (from nbconvert->notebook->open3d) (0.8.4)
# Requirement already satisfied: bleach in c:\users\rados\anaconda3\lib\site-packages (from nbconvert->notebook->open3d) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\rados\anaconda3\lib\site-packages (from nbconvert->notebook->open3d) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\rados\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook->open3d) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\rados\anaconda3\lib\site-packages (from jinja2->notebook->open3d) (1.1.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\rados\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook->open3d) (227)
# Requirement already satisfied: parso>=0.5.2 in c:\users\rados\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (0.5.2)
# Requirement already satisfied: wcwidth in c:\users\rados\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->open3d) (0.1.8)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\rados\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->open3d) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\rados\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->open3d) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\rados\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->open3d) (0.15.7)
# Requirement already satisfied: webencodings in c:\users\rados\anaconda3\lib\site-packages (from bleach->nbconvert->notebook->open3d) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\rados\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->open3d) (2.2.0)
# Requirement already satisfied: cloudpickle in c:\users\rados\anaconda3\lib\site-packages (1.3.0)

# %% [markdown]
# Initialization

# %%
# %% Imports
import torch
from torch.nn.parameter import Parameter
from utils import ORSet, ANDSet, XORSet
import pylab as pl
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
from visualization import DataSpacePlotter, Error3DSpacePlotter, Error2DSpacePlotter
import h5py
import cloudpickle as cpkl

# %% [markdown]
# Parameters

# %%
# %% Parameters
# Standard ANN parameters
learning_rate = 0.01
num_epochs = 1000
batch_size = 50
dataset_size = 500

# type of binary function that should be trained: "or", "and", "xor"
dataset_type = "or"

stop_condition = 1e-5  # when total error per epoch is lower than this, stop optimization
normalize_factor = 0.0  # weight regularization, now implemented yet
activation = "sigma"  # activation function - "sigma" or "step"

# type of visualization 
vis_type = "3D"
# 1D: shows input/output plot with decission boundary plus epoch (batch) error
# 2D: shows 2D projection of the parameter space +1D for error (represented as hight and color) (using tSNE)
# not fully implemented yet (position in error space not shown)
# also, requires preprocessed data (see "generate_tsnes.py" script)
# 3D: 3 + 1D error space (as volume) representation, error shown as color only.
# mouse to control the view, press "w" to show "wireframe", space to cancel

# %%
# for 2D visualization
if vis_type == "2D":
    n_components = 2
    samples_per_dim = 30
    RANGE = 30
    range_min = -RANGE
    range_max = RANGE
    cmap_name = "plasma"

    h5_filename = "src/precomp_error_space.hdf5"

    def unpickle_h5(h5_dset):
        return cpkl.loads(h5_dset[0].tobytes())

    useful_tsne_params = ["angle", "early_exaggeration", "init", "learning_rate", "method", "metric", "perplexity"]
    if dataset_type == "or":
        tsne_params = {
            "angle": 0.5,
            "early_exaggeration": 40,
            "init": "random",
            "learning_rate": 10,
            "method": "barnes_hut",
            "metric": "euclidean",
            "perplexity": 40
        }
    elif dataset_type == "and":
        tsne_params = {
            "angle": 0.5,
            "early_exaggeration": 40,
            "init": "random",
            "learning_rate": 10,
            "method": "barnes_hut",
            "metric": "euclidean",
            "perplexity": 40
        }
    elif dataset_type == "xor":
        tsne_params = {
            "angle": 0.5,
            "early_exaggeration": 40,
            "init": "random",
            "learning_rate": 10,
            "method": "barnes_hut",
            "metric": "euclidean",
            "perplexity": 40
        }

    hfile = h5py.File(h5_filename, "r+")
    sample_group = hfile[f"{dataset_type}"][f"[{range_min}-{range_max}]"][f"{samples_per_dim}_samples"]
    losses = sample_group["losses"][...]

    color_group = sample_group[f"c_{cmap_name}"]
    point_colors = color_group["colors"][...]

    pt_mean_dist = sample_group.attrs["pt_mean_dist"]

    ncomp_group = sample_group[f"{n_components}D"]

    embed_group = ncomp_group
    for p_name, p_value in tsne_params.items():
        if p_name in useful_tsne_params:
            if f"{p_name}: {p_value}" in embed_group:
                embed_group = embed_group[f"{p_name}: {p_value}"]
            elif f"{p_name}: {float(p_value)}" in embed_group:
                embed_group = embed_group[f"{p_name}: {float(p_value)}"]
            else:
                raise KeyError(f"The precomputed values do not contain the value {p_value} for the tSNE parameter {p_name}.")

    tsne = unpickle_h5(embed_group["tsne"])
    embeded_points = embed_group["embeded_points"][...]

    embeded_pt_mean_dist = embed_group.attrs["embeded_pt_mean_dist"]

# %%
class ManualPerceptron(torch.nn.Module):
    """ Manual - because computing gradient in PyTorch the old fashion way is considered a manual labor
    """

    def __init__(self, n_dims, activation="sigma", index=-1, device=torch.device(0)):
        super().__init__()
        self.index = index
        self.n_dims = n_dims
        self.activation = activation
        self.device = device
        self.total_dims = self.n_dims + 1  # input dimensionality + 1 for bias
        self.weights = Parameter(torch.randn(self.total_dims, device=self.device), requires_grad=False)  # assign random weight + bias

    def forward(self, x):
        if x.size(-1) == self.n_dims:
            x_1 = torch.functional.F.pad(x, (0, 1), "constant", value=1).float()  # just append "1" to the input for the bias term
        else:
            x_1 = x
        x_1 = x_1.view(-1, self.total_dims)  # enables input of [batch x dim] or just [dim] (i.e. single input)

        # compute "response", i.e. the dot product between the input and weights (plus bias)
        response = torch.mm(self.weights.view(1, self.total_dims), x_1.t())  # a.k.a "sum(w_i * x_i) - bias"
        # compute the activation function
        if self.activation == "step":
            activation = torch.relu(torch.sign(response))  # 0-1 step activation function
        elif self.activation == "sigma":
            activation = torch.sigmoid(response)  # sigmoid activation function
        return activation

# %% [markdown]
# Main training function

# %%
def train(net, dataset_loader, n_epochs=5, learning_rate=0.05, stop_condition=0.1, dataset_type="or", normalize_factor=0):
    if vis_type == "1D":
        search_plotter = DataSpacePlotter(net)
    elif vis_type == "2D":
        search_plotter = Error2DSpacePlotter(net, points_2d=embeded_points, losses=losses, colors=point_colors, tsne=tsne)
    elif vis_type == "3D":
        search_plotter = Error3DSpacePlotter(net, operation=dataset_type, activation=net.activation, samples_per_dim=80)
    abort = False

    for epoch in range(n_epochs):
        epoch_error = 0.0
        for batch_no, data in enumerate(dataset_loader, 0):
            X, y_target = data
            X_1 = torch.functional.F.pad(X, (0, 1), "constant", value=1).float()
            batch_size = X.size(0)

            # compute network prediction
            y_predict = net(X_1)
            # error = 1/2(Y_target - Y_predict) ^ 2
            error = (y_target - y_predict)**2 / 2

            # loss = (Y_target - Y_predict) * X
            loss = ((y_target - y_predict).view(1, batch_size) * X_1.t()).t().sum(0)
            # w(t+1) = w(t) + n * loss     (the "normalize_factor" bit is an optional primitive weight regularization)
            net.weights.mul_(1 - normalize_factor).add_(learning_rate * loss)

            epoch_error += error.sum().cpu()
            if vis_type == "1D":
                search_plotter.update(error)
            else:
                if search_plotter.update():
                    print("User requested termination.")
                    abort = True
                    break

        if abort:
            break
        print(f"Epoch {epoch} ended.\n  > epoch loss = {epoch_error:.3f}")
        if vis_type == "1D":
            search_plotter.update_epoch(epoch, epoch_error)

        if epoch_error <= stop_condition:
            print(f"Cumulative loss after epoch {epoch} was {epoch_error}, which satisfies the stopping condition -> terminating training.")
            break
    if vis_type == "1D":
        search_plotter.update(error)
    else:
        search_plotter.destroy()

# %% [markdown]
# Make dataset

# %%
# %% make a dataset

if dataset_type == "or":
    dataset = ORSet(dataset_size, generate_online=False)
elif dataset_type == "and":
    dataset = ANDSet(dataset_size, generate_online=False)
elif dataset_type == "xor":
    dataset = XORSet(dataset_size, generate_online=False)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)

# %% [markdown]
# Setup and run optimization

# %%
perceptron = ManualPerceptron(2, activation=activation)

train(perceptron, train_loader, num_epochs, learning_rate, stop_condition=stop_condition, dataset_type=dataset_type, normalize_factor=normalize_factor)

print(perceptron.weights)

if vis_type == "1D":
    pl.waitforbuttonpress()
# Out:
# Epoch 0 ended.
#   > epoch loss = 16.324
# Epoch 1 ended.
#   > epoch loss = 9.997
# Epoch 2 ended.
#   > epoch loss = 8.583
# Epoch 3 ended.
#   > epoch loss = 7.653
# Epoch 4 ended.
#   > epoch loss = 6.845
# Epoch 5 ended.
#   > epoch loss = 6.129
# Epoch 6 ended.
#   > epoch loss = 5.502
# Epoch 7 ended.
#   > epoch loss = 4.956
# Epoch 8 ended.
#   > epoch loss = 4.481
# Epoch 9 ended.
#   > epoch loss = 4.067
# Epoch 10 ended.
#   > epoch loss = 3.705
# Epoch 11 ended.
#   > epoch loss = 3.388
# Epoch 12 ended.
#   > epoch loss = 3.109
# Epoch 13 ended.
#   > epoch loss = 2.861
# Epoch 14 ended.
#   > epoch loss = 2.642
# Epoch 15 ended.
#   > epoch loss = 2.445
# Epoch 16 ended.
#   > epoch loss = 2.270
# Epoch 17 ended.
#   > epoch loss = 2.112
# Epoch 18 ended.
#   > epoch loss = 1.969
# Epoch 19 ended.
#   > epoch loss = 1.841
# Epoch 20 ended.
#   > epoch loss = 1.724
# Epoch 21 ended.
#   > epoch loss = 1.617
# Epoch 22 ended.
#   > epoch loss = 1.520
# Epoch 23 ended.
#   > epoch loss = 1.431
# Epoch 24 ended.
#   > epoch loss = 1.350
# Epoch 25 ended.
#   > epoch loss = 1.275
# Epoch 26 ended.
#   > epoch loss = 1.206
# Epoch 27 ended.
#   > epoch loss = 1.143
# Epoch 28 ended.
#   > epoch loss = 1.084
# Epoch 29 ended.
#   > epoch loss = 1.029
# Epoch 30 ended.
#   > epoch loss = 0.979
# Epoch 31 ended.
#   > epoch loss = 0.932
# Epoch 32 ended.
#   > epoch loss = 0.888
# Epoch 33 ended.
#   > epoch loss = 0.847
# Epoch 34 ended.
#   > epoch loss = 0.809
# Epoch 35 ended.
#   > epoch loss = 0.773
# Epoch 36 ended.
#   > epoch loss = 0.740
# Epoch 37 ended.
#   > epoch loss = 0.708
# User requested termination.
# Parameter containing:
# tensor([ 5.5299,  5.6017, -2.3008], device='cuda:0')
